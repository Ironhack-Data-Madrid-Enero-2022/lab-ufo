# %% [markdown]
# # UFO Question
#
# Our data science team has predicted that the Earth is going to be invaded by an alien force in the
# next years. Our only hope is to replicate a device that can block all alien technology in a radius of
# ~300km. Sadly, the device was sold in 2004 to an anonymous buyer to protect her hometown and
# we don't know how contact her again. We know that the device has been active since 2004 in one
# city in the USA, and we want to know where to start our search.
# We've included a dataset called ​ufo.csv​. This dataset contains over 80,000 reports of UFO sightings
# over the last century (all of them verified by the ESA). Using this dataset, try to guess the city in
# which the device has been hidden.

# %%
import pandas as pd

# %%
UFO= pd.read_csv("ufo.csv")
UFO.head()
# Out:
#    Unnamed: 0          datetime                  city state country     shape  \
# 0           0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1           1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2           2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3           3  10/10/1956 21:00                  edna    tx      us    circle
# 4           4  10/10/1960 20:00               kaneohe    hi      us     light
#
#    duration  total_time                                           comments  \
# 0    2700.0  45 minutes  This event took place in early fall around 194...
# 1    7200.0     1-2 hrs  1949 Lackland AFB&#44 TX.  Lights racing acros...
# 2      20.0  20 seconds  Green/Orange circular disc over Chester&#44 En...
# 3      20.0    1/2 hour  My older brother and twin sister were leaving ...
# 4     900.0  15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
#
#   date_posted   latitude   longitude  year     distance
# 0   4/27/2004  29.883056  -97.941111  2004  1242.667772
# 1  12/16/2005  29.384210  -98.581082  2005  1325.486319
# 2   1/21/2008  53.200000   -2.916667  2008  6515.416577
# 3   1/17/2004  28.978333  -96.645833  2004  1211.971352
# 4   1/22/2004  21.418056 -157.803611  2004  6960.923396

# %%
UFO['country'].unique()
# Out:
# array(['us', nan, 'gb', 'ca', 'au', 'de'], dtype=object)

# %%
total_null=UFO.isnull().sum()
total_null
# Out:
# Unnamed: 0        0
# datetime          0
# city              0
# state          5795
# country        9562
# shape          1910
# duration          0
# total_time        0
# comments         14
# date_posted       0
# latitude          0
# longitude         0
# year              0
# distance          0
# dtype: int64

# %%
filtro1=UFO[(UFO["year"]>=2004)&(UFO["country"]=='us')& (UFO['distance'] <= 400)&(UFO['distance'] > 300)]
filtro1
# Out:
#        Unnamed: 0          datetime           city state country     shape  \
# 10             11  10/10/1968 19:00        brevard    nc      us  fireball
# 12             13  10/10/1970 19:00     manchester    ky      us   unknown
# 14             15  10/10/1972 19:00  harlan county    ky      us    circle
# 126           130  10/10/2004 04:18    terre haute    in      us    sphere
# 151           156  10/10/2006 12:37    blairsville    ga      us   unknown
# ...           ...               ...            ...   ...     ...       ...
# 78144       79954    9/8/2005 14:00       morehead    ky      us    circle
# 78417       80231    9/9/2008 22:00    shelbyville    il      us  triangle
# 78491       80312    9/9/2012 23:00    gainesville    ga      us     light
# 78499       80320    9/9/2013 20:20     tuscaloosa    al      us  fireball
# 78504       80326    9/9/2013 21:00      woodstock    ga      us    sphere
#
#        duration  total_time  \
# 10        180.0   3 minutes
# 12        180.0   3 minutes
# 14       1200.0   20minutes
# 126         5.0   5 seconds
# 151        10.0    <10 sec.
# ...         ...         ...
# 78144     300.0       5 min
# 78417       7.0   7 seconds
# 78491       5.0   5 seconds
# 78499      60.0        1:00
# 78504      20.0  20 seconds
#
#                                                 comments date_posted  \
# 10     silent red /orange mass of energy floated by t...   6/12/2008
# 12     Slow moving&#44 silent craft accelerated at an...   2/14/2008
# 14     On october 10&#44 1972 myself&#44my 5yrs.daugh...   9/15/2005
# 126    silently&#44 it came over my head from behind;...  10/27/2004
# 151    Intermittant streak by moon&#44 not seen on ph...  10/30/2006
# ...                                                  ...         ...
# 78144   Metallic&#44 circular object seen in daytime sky  10/11/2005
# 78417  triangle &#443 huge bright lights&#44 fly over...  10/31/2008
# 78491                                      Ball of light   9/24/2012
# 78499  White/green object much larger than &quot;shoo...   9/30/2013
# 78504  Driving 575 at 21:00 hrs saw a white and green...   9/30/2013
#
#         latitude  longitude  year    distance
# 10     35.233333 -82.734444  2008  393.707403
# 12     37.153611 -83.761944  2008  302.476051
# 14     36.843056 -83.321944  2005  330.895925
# 126    39.466667 -87.413889  2004  366.596468
# 151    34.876111 -83.958333  2006  305.862395
# ...          ...        ...   ...         ...
# 78144  38.183889 -83.432778  2005  381.173108
# 78417  39.406389 -88.790000  2008  393.267915
# 78491  34.297778 -83.824167  2012  351.535135
# 78499  33.209722 -87.569167  2013  335.454679
# 78504  34.101389 -84.519444  2013  318.719195
#
# [1655 rows x 14 columns]

# %%
type(filtro1)
# Out:
# pandas.core.frame.DataFrame

# %%
minlat= min(list(filtro1['latitude']))
minlon= min(list(filtro1['longitude']))
maxlat= max(list(filtro1['latitude']))

# %%
maxlat
# Out:
# 39.7627778

# %%
minlon
# Out:
# -91.0972222

# %%
import folium

# %%
mapa2=folium.Map(location=[maxlat, minlon], tiles='stamentoner', zoom_start=2)

lat=list(filtro1['latitude'])
lng=list(filtro1['longitude'])

for i in range(len(lat)):
    folium.Marker([lat[i], lng[i]], icon=folium.Icon(color='red')).add_to(mapa2)
mapa2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_02fc807043c74fe2a4e48cc65432b47a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_02fc807043c74fe2a4e48cc65432b47a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_02fc807043c74fe2a4e48cc65432b47a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_02fc807043c74fe2a4e48cc65432b47a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.7627778%2C%20-91.0972222%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# The device has been hidden in Nashville
