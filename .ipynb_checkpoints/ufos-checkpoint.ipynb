# %% [markdown]
# # UFO Question
#
# Our data science team has predicted that the Earth is going to be invaded by an alien force in the
# next years. Our only hope is to replicate a device that can block all alien technology in a radius of
# ~300km. Sadly, the device was sold in 2004 to an anonymous buyer to protect her hometown and
# we don't know how contact her again. We know that the device has been active since 2004 in one
# city in the USA, and we want to know where to start our search.
# We've included a dataset called ​ufo.csv​. This dataset contains over 80,000 reports of UFO sightings
# over the last century (all of them verified by the ESA). Using this dataset, try to guess the city in
# which the device has been hidden.

# %%
# Import libraries

import pandas as pd
import folium
import numpy as np
import re
from folium.plugins import HeatMapWithTime as HMWT
from folium.plugins import HeatMap as HM

# %%
# Import data
df=pd.read_csv("ufo.csv")
df.head()
# Out:
#    Unnamed: 0          datetime                  city state country     shape  \
# 0           0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1           1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2           2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3           3  10/10/1956 21:00                  edna    tx      us    circle
# 4           4  10/10/1960 20:00               kaneohe    hi      us     light
#
#    duration  total_time                                           comments  \
# 0    2700.0  45 minutes  This event took place in early fall around 194...
# 1    7200.0     1-2 hrs  1949 Lackland AFB&#44 TX.  Lights racing acros...
# 2      20.0  20 seconds  Green/Orange circular disc over Chester&#44 En...
# 3      20.0    1/2 hour  My older brother and twin sister were leaving ...
# 4     900.0  15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
#
# ...

# %%
df.shape
# Out:
# (78509, 14)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (78509, 14)

# %%
df.drop(["Unnamed: 0", "shape","duration","total_time","date_posted"],axis=1,inplace=True)

# %%
df.head()
# Out:
#            datetime                  city state country  \
# 0  10/10/1949 20:30            san marcos    tx      us
# 1  10/10/1949 21:00          lackland afb    tx     NaN
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb
# 3  10/10/1956 21:00                  edna    tx      us
# 4  10/10/1960 20:00               kaneohe    hi      us
#
#                                             comments   latitude   longitude  \
# 0  This event took place in early fall around 194...  29.883056  -97.941111
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  29.384210  -98.581082
# 2  Green/Orange circular disc over Chester&#44 En...  53.200000   -2.916667
# 3  My older brother and twin sister were leaving ...  28.978333  -96.645833
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  21.418056 -157.803611
#
#    year     distance
# 0  2004  1242.667772
# 1  2005  1325.486319
# 2  2008  6515.416577
# 3  2004  1211.971352
# 4  2004  6960.923396

# %%
mapa=folium.Map(location=[29.883056, -97.941111],
                tiles='openstreetmap', zoom_start=12)

# %%
def regex_date(x):
    return int("".join(re.findall('\d\d\d\d',x)).lower())

df["datetime"] = df.datetime.apply(regex_date)

# %%
set(df["datetime"])
# Out:
# {1906,
#  1910,
#  1916,
#  1920,
#  1925,
#  1929,
#  1930,
#  1931,
#  1933,
#  1934,
#  1936,
#  1937,
#  1939,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014}

# %%
df_ufo = df[df.datetime > 2003][df.country == "us"][df.distance > 250][df.distance < 350]
df_ufo
# Out:
# <ipython-input-61-c76cae1eaa02>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_ufo = df[df.datetime > 2003][df.country == "us"][df.distance > 250][df.distance < 350]
#        datetime          city state country  \
# 151        2006   blairsville    ga      us
# 253        2012  bean station    tn      us
# 877        2009       memphis    tn      us
# 953        2013       cumming    ga      us
# 954        2013    sneedville    tn      us
# ...         ...           ...   ...     ...
# 77782      2006         salem    il      us
# 77855      2013       cumming    ga      us
# 78056      2013       cumming    ga      us
# 78499      2013    tuscaloosa    al      us
# 78504      2013     woodstock    ga      us
#
#                                                 comments   latitude  \
# 151    Intermittant streak by moon&#44 not seen on ph...  34.876111
# 253    Large cigar shaped flying about 800 feet high....  36.343611
# ...

# %%
mapa2=folium.Map(location=[34.876111, -83.958333], tiles='stamentoner', zoom_start=10)

lat=list(df_ufo['latitude'])
lng=list(df_ufo['longitude'])

for i in range(len(lat)):
    folium.Marker([lat[i], lng[i]], icon=folium.Icon(color='red')).add_to(mapa2)
    
    


mapa2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
df.loc[df['city'] == "nashville"]
#we can see that all records of nashville are BEFORE 2004!! She activates it here, yup, we got here city :)
# Out:
#        datetime       city state country  \
# 1470       1999  nashville    tn      us
# 2255       2001  nashville    tn      us
# 8476       2003  nashville    tn      us
# 9504       1999  nashville    in      us
# 13989      2001  nashville    tn      us
# 19946      1999  nashville    tn      us
# 20200      2001  nashville    tn      us
# 23913      1998  nashville    tn      us
# 25003      2007  nashville    in      us
# 25979      1995  nashville    tn      us
# 26394      2001  nashville    tn      us
# 27823      1998  nashville    tn      us
# 30844      1999  nashville    tn      us
# 31587      2002  nashville    tn      us
# 36601      2009  nashville    nc      us
# 38713      2001  nashville    tn      us
# 41963      1999  nashville    tn      us
# 42598      2011  nashville    nc      us
# 46028      1975  nashville    tn      us
# 46054      1975  nashville    tn      us
# 46689      2003  nashville    tn      us
# 47721      1980  nashville    tn      us
# ...

# %%
# The city is mostl ikely Nashville!! :D
